# %% [markdown]
# # Multitranslation using the Google Translation API,PyDictionary <a href="https://colab.research.google.com/github/lexvieira/MultiTranslator_WithSpeak/blob/main/MultiTranslator_WithSpeak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a> | Github <a style="text-decoration: none;" href="https://github.com/lexvieira/MultiTranslator_WithSpeak" target="_blank"><svg height="32" aria-hidden="true" viewBox="0 0 16 16" version="1.1" width="32" data-view-component="true" class="octicon octicon-mark-github v-align-middle"><path fill-rule="evenodd" d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z"></path></svg></a>
#
# ### First, type the word or text that you want to translate

# %%
#@title Click on the Button > (Play) to start { run: "auto", display-mode: "form" }
LANGUAGES_TRANSLATE = {}
dir = []
def conf_modules():
  # !pip3 install googletrans==4.0.0-rc1 &> /dev/null
  # !pip3 install requests &> /dev/null
  # !pip3 install gTTS pyttsx3 &> /dev/null

  import requests
  import os
  global dir
  dir = list(os.listdir())
  # if not 'google_trans_new' in dir:
  #   print('Installing Dependencies')    
  #   !git clone https://github.com/lushan88a/google_trans_new.git &> /dev/null
  # from google_trans_new.google_trans_new import google_translator 
  # from google_trans_new.constant import LANGUAGES, DEFAULT_SERVICE_URLS  

  from googletrans import Translator, LANGUAGES

  global LANGUAGES_TRANSLATE
  LANGUAGES_TRANSLATE = dict(LANGUAGES)

#   import ipywidgets as widgets
# fruit_list = ['pomegranate', 'watermelon', 'lychee']
# fruit_picker = widgets.Dropdown(options=fruit_list, value='watermelon')

conf_modules()
print("Start")
# print(LANGUAGES_TRANSLATE)
# Out:
# Start

# %%
#@title Type the word that you want to translate in many languages

# print(LANGUAGES_TRANSLATE)

#https://colab.research.google.com/notebooks/snippets/advanced_outputs.ipynb
LIST_LANGUAGES = []

#Not in Use
for k, l in LANGUAGES_TRANSLATE.items():
  LIST_LANGUAGES.append(l)

# print(LIST_LANGUAGES)

#@markdown Text Translated in 7 Languages, include English, Portuguese, Thai, Spanish, French, Polish, Italian

#@markdown Future with selection of Languages to Translate 

#@markdown English is the default languages
text_to_translate = "Translate in many languages and control the speed" #@param {type:"string"}

#select_or_input = "apples" #@param ["apples", "bananas", "oranges"] {allow-input: true}
#from_Language =  "english" #@param ['afrikaans', 'albanian', 'amharic', 'arabic', 'armenian', 'azerbaijani', 'basque', 'belarusian', 'bengali', 'bosnian', 'bulgarian', 'catalan', 'cebuano', 'chichewa', 'chinese (simplified)', 'chinese (traditional)', 'corsican', 'croatian', 'czech', 'danish', 'dutch', 'english', 'esperanto', 'estonian', 'filipino', 'finnish', 'french', 'frisian', 'galician', 'georgian', 'german', 'greek', 'gujarati', 'haitian creole', 'hausa', 'hawaiian', 'hebrew', 'hebrew', 'hindi', 'hmong', 'hungarian', 'icelandic', 'igbo', 'indonesian', 'irish', 'italian', 'japanese', 'javanese', 'kannada', 'kazakh', 'khmer', 'korean', 'kurdish (kurmanji)', 'kyrgyz', 'lao', 'latin', 'latvian', 'lithuanian', 'luxembourgish', 'macedonian', 'malagasy', 'malay', 'malayalam', 'maltese', 'maori', 'marathi', 'mongolian', 'myanmar (burmese)', 'nepali', 'norwegian', 'odia', 'pashto', 'persian', 'polish', 'portuguese', 'punjabi', 'romanian', 'russian', 'samoan', 'scots gaelic', 'serbian', 'sesotho', 'shona', 'sindhi', 'sinhala', 'slovak', 'slovenian', 'somali', 'spanish', 'sundanese', 'swahili', 'swedish', 'tajik', 'tamil', 'tatar', 'telugu', 'thai', 'turkish', 'turkmen', 'ukrainian', 'urdu', 'uyghur', 'uzbek', 'vietnamese', 'welsh', 'xhosa', 'yiddish', 'yoruba', 'zulu'] {allow-input: false}

#Instance of Google Translator
import requests 
from googletrans import Translator
import gtts

import librosa
import IPython.display as ipd
import warnings
warnings.filterwarnings('ignore') 
translator = Translator(service_urls=[
    'translate.google.com'
])

to_translate = text_to_translate

translations = []    

lang_list = {"en": "English","pt":"Portuguese BR","th": "Thai", "es": "Spanish", "fr": "French", "pl": "Polish", "it": "Italian"}
#Translation English <> English (OBS: Don't use the same Language with SRC and TGT)
language = translator.detect(to_translate)

#CreateTokenforTheAudioFile
language_to_translate = { language.lang : LANGUAGES_TRANSLATE[language.lang] }
filename = "translation_lang.mp3"
for k, l in lang_list.items():
    lang_dest = k
    lang_src = "auto"

    # print("\n{}{}{}\n".format(lang_dest, lang_src, language_to_translate))        
    #Translations    
    translation_return = translator.translate(to_translate, dest=lang_dest, src = lang_src)
    
    translation_text = "{}".format(translation_return.text) 
    p = translation_return.pronunciation

    print("{}: {}".format(LANGUAGES_TRANSLATE[k].capitalize(), translation_text)) 
    # make request to google to get synthesis    
    tts = gtts.gTTS(translation_text, lang=k) 
    
    # Saving file and Playing    
    tts.save(filename.replace("_lang","_" + k))
    x, sr = librosa.load(filename.replace("_lang","_" + k)) 
    pa = ipd.Audio(x, rate=sr)
    display(pa)
# Out:
# English: Translate in many languages and control the speed
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Portuguese: Traduza em muitos idiomas e controle a velocidade
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Thai: แปลในหลายภาษาและควบคุมความเร็ว
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Spanish: Traducir en muchos idiomas y controlar la velocidad.
#                 <audio  controls="controls" >
# ...
